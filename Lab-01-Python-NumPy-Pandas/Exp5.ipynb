# %% [markdown]
# # Experiment 5: Load CSV File Using Pandas
#
# **Objective:** Load CSV file and perform initial exploration.

# %%
import pandas as pd

# Create sample CSV data for demonstration
# In practice, you would load from an actual file:
# df = pd.read_csv('data.csv')

# Create sample data
data = {
    'ID': [1, 2, 3, 4, 5],
    'Name': ['John', 'Jane', 'Bob', 'Alice', 'Charlie'],
    'Salary': [50000, 60000, 55000, 65000, 58000],
    'Department': ['Sales', 'IT', 'HR', 'IT', 'Sales']
}

df = pd.DataFrame(data)

print('Loaded Data:')
print(df)

# Save to CSV for reference
# df.to_csv('sample_data.csv', index=False)

# Read CSV
# df_loaded = pd.read_csv('sample_data.csv')
# print(df_loaded)

# CSV with different delimiter
# df_semicolon = pd.read_csv('data.csv', delimiter=';')

# Skip rows
# df_skip = pd.read_csv('data.csv', skiprows=2)
