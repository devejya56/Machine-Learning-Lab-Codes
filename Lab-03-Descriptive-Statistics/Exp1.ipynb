# %% [markdown]
# # Lab 03: Experiment 1 - Load and Explore Data
#
# **Objective:** Load dataset and perform initial exploration for descriptive statistics.

# %%
import pandas as pd
import numpy as np

# Create sample Students Performance dataset
data = {
    'math': [72, 68, 75, 80, 85, 90, 78, 82, 88, 92],
    'reading': [70, 75, 80, 85, 88, 92, 78, 80, 90, 94],
    'writing': [75, 72, 78, 82, 86, 90, 80, 78, 85, 92]
}

df = pd.DataFrame(data)
print('Dataset:')
print(df)

print('\nBasic Info:')
print(f'Shape: {df.shape}')
print(f'Columns: {list(df.columns)}')
